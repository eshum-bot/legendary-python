# %% [markdown]
# <a href="https://colab.research.google.com/github/eshum-bot/legendary-python/blob/main/functions_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello")
# Out:
# hello

# %%
hello

# %%
chill
